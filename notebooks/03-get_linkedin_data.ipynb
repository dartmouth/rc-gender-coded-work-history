# %% [markdown]
# # Get LinkedIn data
#
# ### Inputs:
# - `"../data/derived/linkedin_company_urls_final.csv"`
#
# ### Outputs:
# - `"../data/derived/company_profiles.csv"`
#
#
# ### Purpose:
#
# 1. Add company profile data from Bright Data dataset.

# %%
import pandas as pd

# %%
# companies = pd.read_csv("../data/derived/linkedin_company_urls_final.csv")
companies = pd.read_csv("../data/derived/linkedin_company_urls_precheck.csv")

# %%
companies.columns
# Out:
# Index(['Company Name', 'LinkedIn URL', 'Reasoning', 'Is Valid',
#        'Validated URL'],
#       dtype='object')

# %%
companies["LinkedIn URL"]
# Out:
# 0           https://www.linkedin.com/company/verizon-labs
# 1                   https://in.linkedin.com/company/renew
# 2                   https://www.linkedin.com/company/citi
# 3               https://www.linkedin.com/company/epic1979
# 4          https://www.linkedin.com/company/dc-energy-llc
#                               ...
# 2983    https://www.linkedin.com/company/university-of...
# 2984    https://www.linkedin.com/company/standardchart...
# 2985    https://www.linkedin.com/company/impact-hub-bo...
# 2986            https://www.linkedin.com/company/rapidsos
# 2987    https://www.linkedin.com/company/stepstone-group/
# Name: LinkedIn URL, Length: 2988, dtype: object

# %%
# Bright Data download requies the LinkedIn URL slugs
import re


def get_slug(url: str) -> str | None:
    match = re.search(r"company/([^/\s]+)(?:/|$)", url)
    if match:
        return match.group(1)
    return None


slugs = companies["LinkedIn URL"].apply(get_slug)

# %%
slugs.to_csv("../data/derived/linkedin_company_slugs.csv", index=None, header=["id"])

# %% [markdown]
# Using the slugs, the [Bright Data LinkedIn dataset](https://brightdata.com/cp/datasets/browse/gd_l1vikfnt1wgvvqz95w?id=hl_0ba933c4) was filtered down to the available records:

# %%
bd_data = pd.read_csv("../data/bd_20250422_150813_0.csv")

# %%
companies = companies.set_index(slugs.rename("id"))

# %%
bd_data = bd_data.set_index("id")

# %%
companies = companies.merge(bd_data, on="id", how="left")

# %%
companies = companies.rename(columns={"LinkedIn URL": "scraped_linkedin_url"})
companies.columns = ["_".join(c.lower().split()) for c in companies.columns]
companies
# Out:
#                                 company_name  \
# id
# verizon-labs                    Verizon Labs
# renew                            ReNew Power
# citi                                Citibank
# epic1979                   Epic Systems Corp
# dc-energy-llc                      DC Energy
# ...                                      ...
# yahoo-finance                     Yahoo Inc.
# yaleonline                   Yale University
# yum-brands           Yum China Holding, Inc.
# zero-space-usa-inc  ZeroTurnaround USA, Inc.
# zillow                          Zillow Group
#
#                                                  scraped_linkedin_url  \
# id
# verizon-labs            https://www.linkedin.com/company/verizon-labs
# renew                           https://in.linkedin.com/company/renew
# citi                            https://www.linkedin.com/company/citi
# epic1979                    https://www.linkedin.com/company/epic1979
# dc-energy-llc          https://www.linkedin.com/company/dc-energy-llc
# ...                                                               ...
# yahoo-finance          https://www.linkedin.com/company/yahoo-finance
# yaleonline                https://www.linkedin.com/company/yaleonline
# yum-brands                https://www.linkedin.com/company/yum-brands
# zero-space-usa-inc  https://www.linkedin.com/company/zero-space-us...
# zillow                   https://www.linkedin.com/company/zillow/jobs
#
#                                    name  \
# id
# verizon-labs               Verizon Labs
# renew                             ReNew
# citi                               Citi
# epic1979                           Epic
# dc-energy-llc                 DC Energy
# ...                                 ...
# yahoo-finance             Yahoo Finance
# yaleonline                  Yale Online
# yum-brands                  Yum! Brands
# zero-space-usa-inc  Zero Space USA Inc.
# zillow                           Zillow
#
#                                                  country_code  \
# id
# verizon-labs                                              NaN
# renew                                                      IN
# citi                US,CA,MY,PA,PE,MX,PH,HK,AE,GB,CO,IN,IL,TW
# epic1979                                                   US
# dc-energy-llc                                              US
# ...                                                       ...
# yahoo-finance                                              US
# yaleonline                                                 US
# yum-brands                                                 US
# zero-space-usa-inc                                         US
# zillow                                                     US
#
#                                                             locations  \
# id
# verizon-labs                                                       []
# renew               ["Commercial Block, Zone 6, Golf Course Road D...
# citi                ["388 Greenwich Street New York, New York 1001...
# epic1979                      ["1979 Milky Way Verona, WI 53593, US"]
# dc-energy-llc       ["1600 Tysons Blvd Fifth Floor McLean, Virgini...
# ...                                                               ...
# yahoo-finance                    ["770 Broadway New York, 10003, US"]
# yaleonline           ["301 York St New Haven, Connecticut 06511, US"]
# yum-brands            ["1441 Gardiner Lane Louisville, KY 40213, US"]
# zero-space-usa-inc  ["6255 Providence Way Eastvale, California 928...
# zillow                                    ["Seattle, Washington, US"]
#
#                     followers  employees_in_linkedin  \
# id
# verizon-labs           5157.0                   84.0
# renew                376890.0                 4555.0
# citi                4604840.0               193802.0
# epic1979             831666.0                15723.0
# dc-energy-llc          4109.0                  105.0
# ...                       ...                    ...
# yahoo-finance        122042.0                  546.0
# yaleonline             6085.0                    1.0
# yum-brands           279682.0                 7100.0
# zero-space-usa-inc       14.0                    5.0
# zillow               447752.0                 9069.0
#
#                                                                 about  \
# id
# verizon-labs                                                      NaN
# renew               ReNew is a leading decarbonisation solutions p...
# citi                Citi's mission is to serve as a trusted partne...
# epic1979            Join us in our mission to help the world get w...
# dc-energy-llc       DC Energy is a proprietary trading firm that f...
# ...                                                               ...
# yahoo-finance       Yahoo Finance provides free stock quotes, up-t...
# yaleonline          This is Yale, online. Since its founding in 17...
# yum-brands          Yum! Brands, Inc., based in Louisville, Kentuc...
# zero-space-usa-inc  Zero Space USA Inc, supported by Tsinghua Tong...
# zillow              Join our mission to give the people power to u...
#
#                                                           specialties  \
# id
# verizon-labs                                                      NaN
# renew               Renewable Energy, Solar Energy , Wind Energy ,...
# citi                Banking, Commercial Banking, Investment Bankin...
# epic1979                      healthcare, emr, ehr, phr, and software
# dc-energy-llc                                                     NaN
# ...                                                               ...
# yahoo-finance                                                     NaN
# yaleonline          Education, E-Learning, Mobile Learning, Workpl...
# yum-brands          Quick service restaurants, chicken, pizza, tac...
# zero-space-usa-inc                                                NaN
# zillow              Real Estate, Home Values, Mortgages, Homes for...
#
#                               company_size  ...  \
# id                                          ...
# verizon-labs             10,001+ employees  ...
# renew                1,001-5,000 employees  ...
# citi                     10,001+ employees  ...
# epic1979                 10,001+ employees  ...
# dc-energy-llc             51-200 employees  ...
# ...                                    ...  ...
# yahoo-finance             51-200 employees  ...
# yaleonline                51-200 employees  ...
# yum-brands           1,001-5,000 employees  ...
# zero-space-usa-inc         11-50 employees  ...
# zillow              5,001-10,000 employees  ...
#
#                                                            stock_info  \
# id
# verizon-labs                                                      NaN
# renew                                                             NaN
# citi                {"datetime":"April 21, 2025","id":"C","stock_e...
# epic1979                                                          NaN
# dc-energy-llc                                                     NaN
# ...                                                               ...
# yahoo-finance                                                     NaN
# yaleonline                                                        NaN
# yum-brands                                                        NaN
# zero-space-usa-inc                                                NaN
# zillow                                                            NaN
#
#                                                    get_directions_url  \
# id
# verizon-labs        [{"directions_url":"https://www.bing.com/maps?...
# renew               [{"directions_url":"https://www.bing.com/maps?...
# citi                [{"directions_url":"https://www.bing.com/maps?...
# epic1979            [{"directions_url":"https://www.bing.com/maps?...
# dc-energy-llc       [{"directions_url":"https://www.bing.com/maps?...
# ...                                                               ...
# yahoo-finance       [{"directions_url":"https://www.bing.com/maps?...
# yaleonline          [{"directions_url":"https://www.bing.com/maps?...
# yum-brands          [{"directions_url":"https://www.bing.com/maps?...
# zero-space-usa-inc  [{"directions_url":"https://www.bing.com/maps?...
# zillow              [{"directions_url":"https://www.bing.com/maps?...
#
#                                                           description  \
# id
# verizon-labs             Verizon Labs | 5,157 followers on LinkedIn.
# renew               ReNew | 376,890 followers on LinkedIn. ReNew i...
# citi                Citi | 4,604,840 followers on LinkedIn. Citi&#...
# epic1979            Epic | 831,666 followers on LinkedIn. ...with ...
# dc-energy-llc       DC Energy | 4,109 followers on LinkedIn. DC En...
# ...                                                               ...
# yahoo-finance       Yahoo Finance | 122,042 followers on LinkedIn....
# yaleonline          Yale Online | 6,085 followers on LinkedIn. Exp...
# yum-brands          Yum! Brands | 279,682 followers on LinkedIn. B...
# zero-space-usa-inc  Zero Space USA Inc. | 14 followers on LinkedIn...
# zillow              Zillow | 447,752 followers on LinkedIn. Reimag...
#
#                    additional_info  \
# id
# verizon-labs                   NaN
# renew                          NaN
# citi                           NaN
# epic1979                       NaN
# dc-energy-llc                  NaN
# ...                            ...
# yahoo-finance                  NaN
# yaleonline                     NaN
# yum-brands                     NaN
# zero-space-usa-inc             NaN
# zillow                         NaN
#
#                                                additional_information  \
# id
# verizon-labs        Additional jobs info: Network Operations Cente...
# renew               Additional jobs info: Graduate Engineer (29,65...
# citi                Additional jobs info: Citi (1,410 open jobs). ...
# epic1979            Additional jobs info: Epic (49,985 open jobs)....
# dc-energy-llc       Additional jobs info: Analyst (36,938 open job...
# ...                                                               ...
# yahoo-finance                                                     NaN
# yaleonline          Additional jobs info: Journalist (1,540 open j...
# yum-brands                                                        NaN
# zero-space-usa-inc                                                NaN
# zillow                                                            NaN
#
#                                                   country_codes_array alumni  \
# id
# verizon-labs                                                      NaN    NaN
# renew                                                          ["IN"]    NaN
# citi                ["US","CA","MY","PA","PE","MX","PH","HK","AE",...    NaN
# epic1979                                                       ["US"]    NaN
# dc-energy-llc                                                  ["US"]    NaN
# ...                                                               ...    ...
# yahoo-finance                                                  ["US"]    NaN
# yaleonline                                                     ["US"]    NaN
# yum-brands                                                     ["US"]    NaN
# zero-space-usa-inc                                             ["US"]    NaN
# zillow                                                         ["US"]    NaN
#
#                    alumni_information website_simplified  \
# id
# verizon-labs                      NaN        verizon.com
# renew                             NaN          renew.com
# citi                              NaN      citigroup.com
# epic1979                          NaN           epic.com
# dc-energy-llc                     NaN      dc-energy.com
# ...                               ...                ...
# yahoo-finance                     NaN            yhoo.it
# yaleonline                        NaN    online.yale.edu
# yum-brands                        NaN            yum.com
# zero-space-usa-inc                NaN   zerospaceusa.com
# zillow                            NaN         zillow.com
#
#                                                     unformatted_about
# id
# verizon-labs                                                      NaN
# renew               \n              ReNew is a leading decarbonisa...
# citi                \n              Citi's mission is to serve as ...
# epic1979            \n              Join us in our mission to help...
# dc-energy-llc       \n              DC Energy is a proprietary tra...
# ...                                                               ...
# yahoo-finance       \n              Yahoo Finance provides free st...
# yaleonline                                                        NaN
# yum-brands          \n              Yum! Brands, Inc., based in Lo...
# zero-space-usa-inc                                                NaN
# zillow              \n              Join our mission to give the p...
#
# [2420 rows x 40 columns]

# %%
companies.to_csv("../data/derived/company_profiles.csv")

# %% [markdown]
# ## Determine the impact of missing companies
#
# Let's determine how many samples we lose due to lack of company data.

# %%
admissions_data = pd.read_csv("../data/derived/admissions.csv")

records = pd.Series(
    admissions_data["Job 1 Organization"].tolist(),
    name="Company",
)

record_count = records.value_counts().reset_index()

# %%
missing_companies = companies[companies.company_id.isna()]

# %%
record_count[record_count["Company"].isin(missing_companies.company_name)].merge(
    missing_companies[["company_name", "scraped_linkedin_url"]],
    left_on="Company",
    right_on="company_name",
    how="left",
).drop(columns="company_name")
# Out:
#                                               Company  count  \
# 0                                       Goldman Sachs      3
# 1                   Capital One Financial Corporation      1
# 2                                       CJ O Shopping      1
# 3                                  Duzce Municipality      1
# 4                        Nestle Central & West Africa      1
# 5    Interdisciplinary Institute of Political Economy      1
# 6                                    Trinity Partners      1
# 7                                   Impendi Analytics      1
# 8                                Mason Square Capital      1
# 9                                MaxPoint Interactive      1
# 10                                             UBS AG      1
